# %%
import pandas as pd

# %%
w_happiness = pd.read_csv('data/merged_dataset.csv')

# %%
html = w_happiness.to_html()
f = open('../data.html','w')
f.write(html)
f.close()

# %%
# !cat ../data.html
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>index</th>
#       <th>Country</th>
#       <th>Happiness_Rank</th>
#       <th>Year</th>
#       <th>Happiness_Score</th>
#       <th>Economy(GDP_per_Capita)</th>
#       <th>Family</th>
#       <th>Health(Life_Expectancy)</th>
#       <th>Freedom</th>
#       <th>Trust(Government_Corruption)</th>
#       <th>Generosity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>Switzerland</td>
#       <td>1</td>
#       <td>2015</td>
#       <td>7.5870</td>
#       <td>1.396510</td>
#       <td>1.349510</td>
#       <td>0.941430</td>
#       <td>0.665570</td>
#       <td>0.419780</td>
#       <td>0.296780</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>1</td>
#       <td>Iceland</td>
#       <td>2</td>
#       <td>2015</td>
#       <td>7.5610</td>
# ...
